# %%
from ultralytics import YOLO
import cv2

# Load YOLO model (YOLOv8 is default in ultralytics)
model = YOLO("game.pt")  # You can replace 'yolov8n.pt' with your custom or larger model

# Open webcam (0 is usually the default webcam)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("❌ Cannot open webcam")
    exit()

print("✅ Webcam opened. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to grab frame")
        break

    # Run YOLO inference on the frame
    results = model(frame, stream=True)

    # Draw results
    for r in results:
        annotated_frame = r.plot()

    # Display the output
    cv2.imshow("YOLO Webcam Detection", annotated_frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
cv2.destroyAllWindows()
# Out:
# ✅ Webcam opened. Press 'q' to quit.
#
# 0: 480x640 (no detections), 2155.9ms
# Speed: 78.4ms preprocess, 2155.9ms inference, 36.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1903.9ms
# Speed: 16.1ms preprocess, 1903.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1739.1ms
# Speed: 3.4ms preprocess, 1739.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1757.6ms
# Speed: 2.6ms preprocess, 1757.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1843.7ms
# Speed: 3.3ms preprocess, 1843.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1736.6ms
# Speed: 3.0ms preprocess, 1736.6ms inference, 32.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1710.9ms
# Speed: 3.4ms preprocess, 1710.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1793.7ms
# Speed: 3.6ms preprocess, 1793.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1744.7ms
# Speed: 3.0ms preprocess, 1744.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1739.0ms
# Speed: 2.8ms preprocess, 1739.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1750.3ms
# Speed: 3.3ms preprocess, 1750.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1767.1ms
# Speed: 3.0ms preprocess, 1767.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1757.8ms
# Speed: 3.1ms preprocess, 1757.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1847.2ms
# Speed: 3.0ms preprocess, 1847.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1842.2ms
# Speed: 3.0ms preprocess, 1842.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1960.1ms
# Speed: 3.9ms preprocess, 1960.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1814.1ms
# Speed: 2.7ms preprocess, 1814.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 2015.5ms
# Speed: 76.7ms preprocess, 2015.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1835.4ms
# Speed: 3.1ms preprocess, 1835.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1864.4ms
# Speed: 2.9ms preprocess, 1864.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1949.3ms
# Speed: 4.7ms preprocess, 1949.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1828.8ms
# Speed: 3.5ms preprocess, 1828.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1935.7ms
# Speed: 3.1ms preprocess, 1935.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1865.0ms
# Speed: 3.3ms preprocess, 1865.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 2038.2ms
# Speed: 3.0ms preprocess, 2038.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
